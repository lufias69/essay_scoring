# %%
import pandas as pd
from sklearn.metrics import classification_report
from sklearn.metrics import precision_recall_fscore_support
from sklearn.metrics import accuracy_score

# %%
metode_list = ["cosine", 'dice', 'jaccard']
praproses_list = ["True", "False"]
target_names = ["1", "0", "9"]

precision_true = list()
precision_false = list()
recal_true = list()
recal_false = list()
f_score_true = list()
f_score_false = list()
akurasi_true = list()
akurasi_false = list()

for praproses in praproses_list:
    for metode in metode_list:
        data = pd.read_excel("hasil skor/hasil_"+metode+"_praproses_"+praproses+".xlsx")
        prediksi = data['prediksi_'].tolist()
        asli = data['label asli'].tolist()
        y_true = [str(x) for x in asli]
        y_pred = [str(x) for x in prediksi]
        print("Metode:",metode,"||  ", "Praproses:",praproses)
        print(classification_report(y_true, y_pred, target_names=target_names))
        print("="*100)
        print("")
        
        if praproses == "True":
            hasil = list(precision_recall_fscore_support(y_true, y_pred, average='weighted'))
            precision_true.append(hasil[0])
            recal_true.append(hasil[1])
            f_score_true.append(hasil[2])
            akurasi_true.append(accuracy_score(y_true, y_pred))
        else:
            hasil = list(precision_recall_fscore_support(y_true, y_pred, average='weighted'))
            precision_false.append(hasil[0])
            recal_false.append(hasil[1])
            f_score_false.append(hasil[2])
            akurasi_false.append(accuracy_score(y_true, y_pred))
    print("*"*100)
# Out:
# Metode: cosine ||   Praproses: True
#               precision    recall  f1-score   support
#
#            1       0.98      0.92      0.95      1220
#            0       0.90      0.97      0.93       865
#            9       0.83      1.00      0.91         5
#
#     accuracy                           0.94      2090
#    macro avg       0.90      0.97      0.93      2090
# weighted avg       0.95      0.94      0.94      2090
#
# ====================================================================================================
#
# Metode: dice ||   Praproses: True
#               precision    recall  f1-score   support
#
#            1       0.98      0.93      0.95      1220
#            0       0.90      0.97      0.93       865
#            9       0.83      1.00      0.91         5
#
#     accuracy                           0.94      2090
#    macro avg       0.90      0.96      0.93      2090
# weighted avg       0.95      0.94      0.94      2090
#
# ====================================================================================================
#
# Metode: jaccard ||   Praproses: True
#               precision    recall  f1-score   support
#
#            1       0.91      0.97      0.94      1220
#            0       0.95      0.86      0.91       865
#            9       0.83      1.00      0.91         5
#
#     accuracy                           0.93      2090
#    macro avg       0.90      0.94      0.92      2090
# weighted avg       0.93      0.93      0.93      2090
#
# ====================================================================================================
#
# ****************************************************************************************************
# Metode: cosine ||   Praproses: False
#               precision    recall  f1-score   support
#
#            1       0.86      0.96      0.91      1220
#            0       0.93      0.78      0.85       865
#            9       0.83      1.00      0.91         5
#
#     accuracy                           0.89      2090
#    macro avg       0.88      0.91      0.89      2090
# weighted avg       0.89      0.89      0.88      2090
#
# ====================================================================================================
#
# Metode: dice ||   Praproses: False
#               precision    recall  f1-score   support
#
#            1       0.89      0.96      0.92      1220
#            0       0.93      0.84      0.88       865
#            9       0.83      1.00      0.91         5
#
#     accuracy                           0.91      2090
#    macro avg       0.89      0.93      0.91      2090
# weighted avg       0.91      0.91      0.91      2090
#
# ====================================================================================================
#
# Metode: jaccard ||   Praproses: False
#               precision    recall  f1-score   support
#
#            1       0.65      1.00      0.79      1220
#            0       0.97      0.24      0.38       865
#            9       0.83      1.00      0.91         5
#
#     accuracy                           0.68      2090
#    macro avg       0.82      0.74      0.69      2090
# weighted avg       0.78      0.68      0.62      2090
#
# ====================================================================================================
#
# ****************************************************************************************************

# %% [markdown]
# # Kesimpulan

# %%
dict_ = {
    "metode":metode_list,
    'precision_false' :precision_false,
    'recal_false' :recal_false,
    'f_score_false' :f_score_false,
    'akurasi_false':akurasi_false,
    
    "|":['|'for i in range(len(akurasi_true))],
    
   'precision_true' :precision_true,
    'recal_true' :recal_true,
    'f_score_true' :f_score_true,
    'akurasi_true' :akurasi_true,
}
perbandingan1 = pd.DataFrame.from_dict(dict_)
perbandingan1
# Out:
#     metode  precision_false  recal_false  f_score_false  akurasi_false  |  \
# 0   cosine         0.891657     0.886603       0.884621       0.886603  |
# 1     dice         0.910368     0.908612       0.907738       0.908612  |
# 2  jaccard         0.782966     0.682297       0.619647       0.682297  |
#
#    precision_true  recal_true  f_score_true  akurasi_true
# 0        0.946582    0.943541      0.943833      0.943541
# 1        0.945920    0.943541      0.943803      0.943541
# 2        0.928077    0.926316      0.925680      0.926316

# %%
dict_ = {
    "metode":metode_list,
    'precision_false' :precision_false,
   'precision_true' :precision_true,
    'recal_false' :recal_false,
    'recal_true' :recal_true,
    'f_score_false' :f_score_false,
    'f_score_true' :f_score_true,
    'akurasi_false':akurasi_false,
    'akurasi_true' :akurasi_true,
    
}
perbandingan1 = pd.DataFrame.from_dict(dict_)
perbandingan1
# Out:
#     metode  precision_false  precision_true  recal_false  recal_true  \
# 0   cosine         0.891657        0.946582     0.886603    0.943541
# 1     dice         0.910368        0.945920     0.908612    0.943541
# 2  jaccard         0.782966        0.928077     0.682297    0.926316
#
#    f_score_false  f_score_true  akurasi_false  akurasi_true
# 0       0.884621      0.943833       0.886603      0.943541
# 1       0.907738      0.943803       0.908612      0.943541
# 2       0.619647      0.925680       0.682297      0.926316
